# %% [markdown]
# <a href="https://colab.research.google.com/github/cauavorpagel/pcd-aulas-iniciais/blob/main/Aula_09_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Pet:
  def __init__(self, nome: str, idade: int, peso: float, cor: str, tipo: str, __castrado=False):
    self.nome = nome
    self.idade = idade
    self.peso = peso
    self.cor = cor
    self.__tipo =tipo
    self.castrado = __castrado

  def setTipo(self, tipo: str):
    self.__tipo = tipo

  def getTipo(self):
    return self.__tipo

  def setCor(self, cor: str):
    self.cor = cor

  def getCor(self):
    return self.cor

  def setCastracao(self):
    self.__anestesia()

  def tipoComida(self):
    return 'monster'

pet = Pet("Cauã", 21, 200.00, 'Caucasiano', 'Nerd/Geek')

print(pet.getCor())
print(pet.getTipo())
# Out:
# Caucasiano
# Nerd/Geek
