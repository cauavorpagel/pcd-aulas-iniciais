# %% [markdown]
# <a href="https://colab.research.google.com/github/cauavorpagel/pcd-aulas-iniciais/blob/main/Aula02_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git config --global user.name "cauavorpagel"
# !git config --global user.email "cauamvorpagel@gmail.com"

# !apt-get -qq update
# !apt-get -qq install gh

# !GH_PROMPT_DISABLED=1 gh auth login --hostname github.com --git-protocol https --web
# !gh auth setup-git

# !git clone https://github.com/cauavorpagel/pcd-aulas-iniciais.git
# %cd pcd-aulas-iniciais
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# (Reading database ... 118419 files and directories currently installed.)
# Preparing to unpack .../archives/gh_2.99.0_amd64.deb ...
# Unpacking gh (2.99.0) over (2.98.0) ...
# Setting up gh (2.99.0) ...
# Processing triggers for man-db (2.10.2-1) ...
#
# ! First copy your one-time code: D8CE-A379
# Open this URL to continue in your web browser: https://github.com/login/device
# ✓ Authentication complete.
# - gh config set -h github.com git_protocol https
# ✓ Configured git protocol
# ! Authentication credentials saved in plain text
# ✓ Logged in as cauavorpagel
# Cloning into 'pcd-aulas-iniciais'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (43/43), done.
# ...

# %%
# !git add .
# !git commit
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
